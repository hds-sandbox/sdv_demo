# %% [markdown]
# Load necessary modules

# %%
import numpy as np
import pandas as pd
from sdv.lite import TabularPreset as TP
from sdv import Metadata

# %% [markdown]
# SDV uses a weird metadata system to be able to model relational data. I suppose that it is highly useful for working with synthetic data in a production setting, but it is mainly an irritation for this example. We also load the data into a data frame as a separate step. This seems like double the effort.

# %%
meta = Metadata()
meta.add_table(name="clltim",
               data='data/cll_synth.csv')
               
clltim = pd.read_csv('data/cll_synth.csv')
clltim.describe()
# Out:
#         Patient_id  Binet_Stage_A  Binet_Stage_B  Binet_Stage_C  \
# count  3000.000000    3000.000000    3000.000000    3000.000000
# mean   1500.500000       0.854333       0.116333       0.029333
# std     866.169729       0.352831       0.320678       0.168767
# min       1.000000       0.000000       0.000000       0.000000
# 25%     750.750000       1.000000       0.000000       0.000000
# 50%    1500.500000       1.000000       0.000000       0.000000
# 75%    2250.250000       1.000000       0.000000       0.000000
# max    3000.000000       1.000000       1.000000       1.000000
#
#        IGHV_unmut_Mutated  IGHV_unmut_Unmutated  IGHV_unmut_NA       ECOG_0  \
# count         3000.000000           3000.000000    3000.000000  3000.000000
# mean             0.450667              0.331667       0.217667     0.782667
# std              0.497643              0.470890       0.412728     0.412500
# min              0.000000              0.000000       0.000000     0.000000
# 25%              0.000000              0.000000       0.000000     1.000000
# 50%              0.000000              0.000000       0.000000     1.000000
# 75%              1.000000              1.000000       0.000000     1.000000
# max              1.000000              1.000000       1.000000     1.000000
#
#             ECOG_1       ECOG_2  ...     INR_mean      INR_max        INR_sd  \
# count  3000.000000  3000.000000  ...  3000.000000  3000.000000  3.000000e+03
# mean      0.176000     0.025667  ...     1.136646     1.190110  5.378933e-02
# std       0.380884     0.158165  ...     0.399444     0.495875  1.991131e-01
# min       0.000000     0.000000  ...     0.246136     0.144209  8.570000e-50
# 25%       0.000000     0.000000  ...     0.855809     0.824274  7.060000e-10
# 50%       0.000000     0.000000  ...     1.087242     1.126298  1.550000e-05
# 75%       0.000000     0.000000  ...     1.375890     1.485011  7.854461e-03
# max       1.000000     1.000000  ...     3.497131     4.026163  2.774942e+00
#
#            NA+_min      NA+_max       NA+_sd     NA+_mean  \
# count  2669.000000  2669.000000  2669.000000  2669.000000
# mean    139.313660   152.855185     5.906128   146.042010
# std      11.872978    14.912916     6.744991    10.799180
# min      83.417708   113.297819     0.000000   113.297819
# 25%     133.050884   141.652636     0.000000   138.776070
# 50%     137.813969   148.621803     3.311764   143.323587
# 75%     144.324539   163.319389    10.119194   152.764630
# max     208.357356   211.256674    38.979306   208.357356
#
#        INFEC_interval_mean  infec_90_days_mean  INFEC_after_diag
# count          3000.000000         3000.000000       3000.000000
# mean              0.245000            3.426000          0.314333
# std               2.744963           12.910722          0.464327
# min               0.000000            0.000000          0.000000
# 25%               0.000000            0.000000          0.000000
# 50%               0.000000            0.000000          0.000000
# 75%               0.000000            0.000000          1.000000
# max             114.000000          156.000000          1.000000
#
# [8 rows x 172 columns]

# %% [markdown]
# Before anything else we will try using one of the TabularPresets loaded as `TP`

# %%
fml = TP(name='FAST_ML',
         metadata=meta.get_table_meta('clltim'))

# %% [markdown]
# So far so good, now it is time to fit a model using the TabularPreset `fml`

# %%
fml.fit(clltim)
# Out:
# C:\Users\wxqg\.virtualenvs\sdv-V2IxAAAW\lib\site-packages\sdv\lite\tabular.py:116: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, column_data in data.iteritems():

# %% [markdown]
# Easy peasy lemon squeezy. Lets generate some samples

# %%
fml.sample(10)
# Out:
#    Patient_id  Binet_Stage_A  Binet_Stage_B  Binet_Stage_C  \
# 0        1564              1              0              0
# 1        1837              1              0              0
# 2         469              1              0              0
# 3         935              1              0              0
# 4        2189              1              0              0
# 5        1506              1              0              0
# 6         770              1              0              0
# 7           1              1              0              0
# 8         827              1              0              0
# 9           1              0              0              0
#
#    IGHV_unmut_Mutated  IGHV_unmut_Unmutated  IGHV_unmut_NA  ECOG_0  ECOG_1  \
# 0                   0                     0              1       0       0
# 1                   0                     1              0       1       0
# 2                   0                     1              0       0       0
# 3                   1                     0              0       0       1
# 4                   0                     0              1       0       1
# 5                   0                     1              0       1       0
# 6                   0                     0              1       1       0
# 7                   0                     1              0       1       0
# 8                   0                     1              0       1       0
# 9                   0                     0              0       1       0
#
#    ECOG_2  ...  INR_mean   INR_max        INR_sd     NA+_min     NA+_max  \
# 0       0  ...  1.271823  1.406492  8.570000e-50  137.191700  164.535641
# 1       0  ...  0.834000  0.776977  5.351581e-02         NaN  176.901830
# 2       0  ...  0.901627  0.585938  3.641376e-02  145.971547  159.916061
# 3       0  ...  1.395946  1.286805  2.014153e-02         NaN  144.387953
# 4       0  ...  0.785447  0.902272  1.657832e-01  154.219380         NaN
# 5       0  ...  0.915938  0.934134  2.263182e-01  143.656185         NaN
# 6       0  ...  0.246136  0.144209  8.570000e-50  128.283537  159.723838
# 7       0  ...  1.792619  1.648986  1.685006e-01  144.490563  170.901373
# 8       0  ...  1.352963  1.375220  5.206771e-01  143.019293  158.618944
# 9       0  ...  1.137187  1.186354  8.570000e-50  133.562082  173.547127
#
#       NA+_sd    NA+_mean  INFEC_interval_mean  infec_90_days_mean  \
# 0  13.341147  151.802831                    0                  11
# 1        NaN  163.123336                    0                   0
# 2   6.028226  153.271321                    0                   5
# 3        NaN  140.615399                    3                   0
# 4        NaN  158.424905                    1                  28
# 5   4.582707  149.956129                    0                   2
# 6  13.476621  144.740409                    0                   6
# 7        NaN  157.860203                    1                  10
# 8   7.982769  153.915688                    1                  11
# 9  16.420656  154.133956                    0                   0
#
#    INFEC_after_diag
# 0                 0
# 1                 0
# 2                 0
# 3                 1
# 4                 1
# 5                 0
# 6                 1
# 7                 0
# 8                 1
# 9                 0
#
# [10 rows x 172 columns]

# %% [markdown]
# Okay cool, but notice that some onehot encoded features have multiple "hot" values in a single row. We should introduce some constraints.

# %%
from sdv.constraints import OneHotEncoding

# %%
binet_ohe   =     OneHotEncoding(['Binet_Stage_A', 'Binet_Stage_B', 'Binet_Stage_C'])
ighv_ohe    =     OneHotEncoding(clltim.columns[4:7])
ecog_ohe    =     OneHotEncoding(clltim.columns[7:14])
famcll_ohe  =     OneHotEncoding(clltim.columns[14:17])
beta2_ohe   =     OneHotEncoding(clltim.columns[17:20])
cd38_ohe    =     OneHotEncoding(clltim.columns[20:23])
zap70_ohe   =     OneHotEncoding(clltim.columns[23:26])
gender_ohe  =     OneHotEncoding(clltim.columns[26:28])
del13_ohe   =     OneHotEncoding(clltim.columns[28:31])
tri12_ohe   =     OneHotEncoding(clltim.columns[31:34])
del11_ohe   =     OneHotEncoding(clltim.columns[34:37])
fml_constraints = [binet_ohe, ighv_ohe, ecog_ohe, famcll_ohe, beta2_ohe, cd38_ohe, zap70_ohe,
               gender_ohe, del13_ohe, tri12_ohe, del11_ohe]

# %% [markdown]
# Inspect the constraints

# %%
for c in fml_constraints:
    print(c.to_dict())
# Out:
# {'constraint': 'sdv.constraints.tabular.OneHotEncoding', 'column_names': ['Binet_Stage_A', 'Binet_Stage_B', 'Binet_Stage_C']}
# {'constraint': 'sdv.constraints.tabular.OneHotEncoding', 'column_names': Index(['IGHV_unmut_Mutated', 'IGHV_unmut_Unmutated', 'IGHV_unmut_NA'], dtype='object')}
# {'constraint': 'sdv.constraints.tabular.OneHotEncoding', 'column_names': Index(['ECOG_0', 'ECOG_1', 'ECOG_2', 'ECOG_3', 'ECOG_4', 'ECOG_5', 'ECOG_NA'], dtype='object')}
# {'constraint': 'sdv.constraints.tabular.OneHotEncoding', 'column_names': Index(['FamCLL_Yes', 'FamCLL_No', 'FamCLL_NA'], dtype='object')}
# {'constraint': 'sdv.constraints.tabular.OneHotEncoding', 'column_names': Index(['Beta2m_Yes', 'Beta2m_No', 'Beta2m_NA'], dtype='object')}
# {'constraint': 'sdv.constraints.tabular.OneHotEncoding', 'column_names': Index(['CD38_Yes', 'CD38_No', 'CD38_NA'], dtype='object')}
# {'constraint': 'sdv.constraints.tabular.OneHotEncoding', 'column_names': Index(['ZAP70_Yes', 'ZAP70_No', 'ZAP70_NA'], dtype='object')}
# {'constraint': 'sdv.constraints.tabular.OneHotEncoding', 'column_names': Index(['Gender_M', 'Gender_F'], dtype='object')}
# {'constraint': 'sdv.constraints.tabular.OneHotEncoding', 'column_names': Index(['del13_Yes', 'del13_No', 'del13_NA'], dtype='object')}
# {'constraint': 'sdv.constraints.tabular.OneHotEncoding', 'column_names': Index(['tri12_Yes', 'tri12_No', 'tri12_NA'], dtype='object')}
# {'constraint': 'sdv.constraints.tabular.OneHotEncoding', 'column_names': Index(['del11_Yes', 'del11_No', 'del11_NA'], dtype='object')}

# %% [markdown]
# Let's sample again, this time using the constraints

# %%
fml_constrained = TP("FAST_ML", metadata=meta.get_table_meta('clltim'), constraints=fml_constraints)
fml_constrained.fit(clltim)

# %%
fml_constrained.sample(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fml_constrained.sample(10)
#
# NameError: name 'fml_constrained' is not defined

# %% [markdown]
# We impose certain constraints on continuous values, we can use several other constraints

# %%
import sdv.constraints as constraints
import re

# %%
for c in map(lambda x: constraints.ScalarInequality(x, '>=', 0), clltim.columns[39:-3]):
    if c not in fml_constraints:
        fml_constraints.append(c)

# %%
len(fml_constraints)
# Out:
# 141

# %%
fml_highly_constrained = TP(name='FAST_ML', metadata=meta.get_table_meta('clltim'), constraints=fml_constraints)
fml_highly_constrained.fit(clltim)

# %%
fml_highly_constrained.sample(10, max_tries_per_batch=1000)
# Out:
# Sampling rows:  10%|███████████████▎                                                                                                                                         | 1/10 [38:04<5:42:36, 2284.01s/it]
#    Patient_id  Binet_Stage_A  Binet_Stage_B  Binet_Stage_C  \
# 0        1665              1              0              0
#
#    IGHV_unmut_Mutated  IGHV_unmut_Unmutated  IGHV_unmut_NA  ECOG_0  ECOG_1  \
# 0                   1                     0              0       1       0
#
#    ECOG_2  ...  INR_mean   INR_max    INR_sd     NA+_min     NA+_max  \
# 0       0  ...  0.841381  0.930088  0.030767  121.159132  133.496404
#
#      NA+_sd    NA+_mean  INFEC_interval_mean  infec_90_days_mean  \
# 0  8.346455  129.092974                    0                   0
#
#    INFEC_after_diag
# 0                 0
#
# [1 rows x 172 columns]

# %% [markdown]
# ALAS! The number of constraints is very high, so the time it takes to generate a sample is also very long. In fact, it may not succeed within the allowed number of tries (1000 per row). Remember, we chose the `FAST_ML` option, so other models may be even slower at generating constrained samples. Then again, other models may fit the data better and be better at complying to the constraints.

# %%
clltim.columns.to_list()

# %%
from sdv.tabular import CTGAN
fml_ohe_constraints = [binet_ohe, ighv_ohe, ecog_ohe, famcll_ohe, beta2_ohe, cd38_ohe, zap70_ohe,
               gender_ohe, del13_ohe, tri12_ohe, del11_ohe]

no_constrain_GAN = CTGAN(table_metadata=meta.get_table_meta('clltim'))
no_constrain_GAN.fit(clltim)
